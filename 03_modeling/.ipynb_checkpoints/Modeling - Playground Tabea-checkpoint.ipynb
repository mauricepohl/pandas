# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../00_data/data_with_calc_fields.csv", sep=";", decimal=",", index_col="datetime")
data.index = pd.to_datetime(data.index)
data.head(3)
# Out:
#                            date  hour  day_ahead_price  intraday_price  \
# datetime
# 2016-01-01 00:00:00  2016-01-01     0            23.86           29.34
# 2016-01-01 01:00:00  2016-01-01     1            22.39           24.28
# 2016-01-01 02:00:00  2016-01-01     2            20.59           25.26
#
#                      price_diff  solar_capacity  solar_generation_actual  \
# datetime
# 2016-01-01 00:00:00        5.48           39021                        0
# 2016-01-01 01:00:00        1.89           39021                        0
# 2016-01-01 02:00:00        4.67           39021                        0
#
#                      wind_capacity  wind_generation_actual  \
# datetime
# 2016-01-01 00:00:00          44325                    8648
# 2016-01-01 01:00:00          44325                    8579
# 2016-01-01 02:00:00          44325                    8542
#
#                      wind_generation_forecast   ...     \
# datetime                                        ...
# 2016-01-01 00:00:00                      6033   ...
# 2016-01-01 01:00:00                      7421   ...
# 2016-01-01 02:00:00                      7266   ...
#
#                      mov_avg_10_wind_forecast_error  \
# datetime
# 2016-01-01 00:00:00                     2615.000000
# 2016-01-01 01:00:00                     1883.464583
# 2016-01-01 02:00:00                     1679.286653
#
#                      mov_avg_10_solar_forecast_error  \
# datetime
# 2016-01-01 00:00:00                              0.0
# 2016-01-01 01:00:00                              0.0
# 2016-01-01 02:00:00                              0.0
#
#                      mov_avg_1_forecast_error  mov_avg_1_wind_forecast_error  \
# datetime
# 2016-01-01 00:00:00               2615.000000                    2615.000000
# 2016-01-01 01:00:00               1856.145833                    1856.145833
# 2016-01-01 02:00:00               1646.434355                    1646.434355
#
#                      mov_avg_1_solar_forecast_error  mov_avg_1_day_ahead  \
# datetime
# 2016-01-01 00:00:00                             0.0            23.860000
# 2016-01-01 01:00:00                             0.0            23.094375
# 2016-01-01 02:00:00                             0.0            22.189092
#
#                      mov_avg_1_intraday  season  month  weekday
# datetime
# 2016-01-01 00:00:00           29.340000       0      1        4
# 2016-01-01 01:00:00           26.704583       0      1        4
# 2016-01-01 02:00:00           26.182394       0      1        4
#
# [3 rows x 34 columns]

# %%
data.describe()
# Out:
#                hour  day_ahead_price  intraday_price    price_diff  \
# count  17542.000000     17542.000000    17542.000000  17542.000000
# mean      11.501083        31.588521       31.760971      0.172451
# std        6.922035        15.483638       16.573758      6.831890
# min        0.000000      -130.090000     -155.520000    -62.710000
# 25%        6.000000        24.010000       23.912500     -2.890000
# 50%       12.000000        31.070000       31.300000      0.030000
# 75%       17.750000        38.100000       38.747500      2.950000
# max       23.000000       163.520000      200.430000    106.080000
#
#        solar_capacity  solar_generation_actual  wind_capacity  \
# count    17542.000000             17542.000000   17542.000000
# mean     40306.320773              4015.817296   49534.509007
# std        926.067096              6175.382183    3376.046418
# min      39021.000000                 0.000000   44325.000000
# 25%      39484.000000                 0.000000   46779.000000
# 50%      40293.000000               115.000000   49569.000000
# 75%      41191.000000              6396.750000   52544.000000
# max      41951.000000             27634.000000   55790.000000
#
#        wind_generation_actual  wind_generation_forecast  \
# count            17542.000000              17542.000000
# mean             10239.222951              10113.905199
# std               8024.646794               7841.336319
# min                135.000000                291.000000
# 25%               4024.000000               4073.250000
# 50%               8041.500000               7980.500000
# 75%              14318.750000              13818.000000
# max              39231.000000              40368.000000
#
#        solar_generation_forecast      ...       \
# count               17542.000000      ...
# mean                 4041.170904      ...
# std                  6169.258742      ...
# min                     0.000000      ...
# 25%                     0.000000      ...
# 50%                   145.500000      ...
# 75%                  6458.000000      ...
# max                 27523.000000      ...
#
#        mov_avg_10_wind_forecast_error  mov_avg_10_solar_forecast_error  \
# count                    17542.000000                     17542.000000
# mean                       114.104948                       -26.232457
# std                        443.735395                       159.166038
# min                      -2123.066539                      -639.919469
# 25%                       -177.039362                      -116.090070
# 50%                        106.263209                       -33.302650
# 75%                        392.905248                        46.823669
# max                       2615.000000                       563.709523
#
#        mov_avg_1_forecast_error  mov_avg_1_wind_forecast_error  \
# count              17542.000000                   17542.000000
# mean                 100.103553                     125.593806
# std                 1045.531732                     962.158482
# min                -4782.832873                   -4722.598413
# 25%                 -524.553780                    -397.880602
# 50%                   74.300932                      63.989261
# 75%                  702.220684                     636.550677
# max                 5243.519482                    5236.840815
#
#        mov_avg_1_solar_forecast_error  mov_avg_1_day_ahead  \
# count                    17542.000000         17542.000000
# mean                       -25.490253            31.599555
# std                        359.012229            11.845245
# min                      -2113.039116           -60.052962
# 25%                       -192.896952            25.837453
# 50%                        -29.787620            30.947969
# 75%                        143.132587            36.756713
# max                       2252.969291           108.868399
#
#        mov_avg_1_intraday        season         month       weekday
# count        17542.000000  17542.000000  17542.000000  17542.000000
# mean            31.774236      1.507696      6.520237      3.007867
# std             12.542189      1.117376      3.449641      2.000583
# min            -44.646698      0.000000      1.000000      0.000000
# 25%             25.480078      1.000000      4.000000      1.000000
# 50%             31.242419      2.000000      7.000000      3.000000
# 75%             37.519552      3.000000     10.000000      5.000000
# max            125.297841      3.000000     12.000000      6.000000
#
# [8 rows x 33 columns]

# %%
x = data["price_diff"]
y1 = data["solar_forecast_error"]
y2 = data["wind_forecast_error"]
y3 = data["forecast_error"]

f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20, 20), sharex=True)
ax1.scatter(x, y1)
ax1.set_title("Solar Forecast Error vs. Price Difference")
ax1.set_ylim(-5000,5000)
z = np.polyfit(x, y1, 1)
p = np.poly1d(z)
ax1.plot(x,p(x),"r--")
ax2.scatter(x, y2)
ax2.set_title("Wind Forecast Error vs. Price Difference");
ax2.set_ylim(-5000,5000)
z = np.polyfit(x, y2, 1)
p = np.poly1d(z)
ax2.plot(x,p(x),"r--")
ax3.scatter(x, y3)
ax3.set_title("Total Forecast Error vs. Price Difference");
ax3.set_ylim(-5000,5000)
z = np.polyfit(x, y2, 1)
p = np.poly1d(z)
ax3.plot(x,p(x),"r--")
for a in [ax1, ax2, ax3]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')

# %%
print("Wind forecast error pairplots")
sns.pairplot(data, x_vars=["hour", "weekday", "month", "season"], y_vars="wind_forecast_error", hue="month", diag_kind = 'kde', height=9)
# Out:
# Wind forecast error pairplots

# %%
print("Solar forecast error pairplots")
sns.pairplot(data, x_vars=["hour", "weekday", "month", "season"], y_vars="solar_forecast_error", hue="month", diag_kind = 'kde', height=9)

# %%
print("Wind forecast error relationships to wind generation forecast and moving averages of wind forecast error for 1, 10, 30 days")
data["wind_forecast_error_shifted"] = data["wind_forecast_error"].shift(-24)
sns.pairplot(data, x_vars=["wind_generation_forecast", "mov_avg_30_wind_forecast_error", "mov_avg_10_wind_forecast_error", "mov_avg_1_wind_forecast_error"], y_vars="wind_forecast_error_shifted", hue="month", diag_kind = 'kde', height=9)

# %%
print("Solar forecast error relationships to solar generation forecast and moving averages of solar forecast error for 1, 10, 30 days")
data["solar_forecast_error_shifted"] = data["solar_forecast_error"].shift(-24)
sns.pairplot(data, x_vars=["weekday", "hour", "month", "solar_generation_forecast", "mov_avg_30_solar_forecast_error", "mov_avg_10_solar_forecast_error", "mov_avg_1_solar_forecast_error"], y_vars="solar_forecast_error_shifted", hue="month", diag_kind = 'kde', height=9)
