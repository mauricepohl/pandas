# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../00_data/merged_all_with_datetime_by_algo.csv", sep=";", decimal=",", index_col=["datetime"])
data
# Out:
#                            date  hour  day_ahead_price  intraday_price  \
# datetime
# 2016-01-01 01:00:00  2016-01-01     1            22.39           24.28
# 2016-01-01 02:00:00  2016-01-01     2            20.59           25.26
# 2016-01-01 03:00:00  2016-01-01     3            16.81           20.24
# 2016-01-01 04:00:00  2016-01-01     4            17.41           21.94
# 2016-01-01 05:00:00  2016-01-01     5            17.02           23.50
# 2016-01-01 06:00:00  2016-01-01     6            15.86           21.87
# 2016-01-01 07:00:00  2016-01-01     7            18.16           25.13
# 2016-01-01 08:00:00  2016-01-01     8            17.73           24.52
# 2016-01-01 09:00:00  2016-01-01     9            19.77           23.67
# 2016-01-01 10:00:00  2016-01-01    10            23.75           25.64
# 2016-01-01 11:00:00  2016-01-01    11            26.03           27.80
# 2016-01-01 12:00:00  2016-01-01    12            27.06           29.75
# ...

# %%
x = data["price_diff"]
y1 = data["DE_solar_generation_error"]
y2 = data["DE_wind_generation_error"]
y3 = data["forecast_error"]

f, (ax1, ax2, ax3) = plt.subplots(2, 1, figsize=(20, 10), sharex=True)
ax1.scatter(x, y1)
ax1.set_title("Solar Forecast Error vs. Price Difference")
ax2.scatter(x, y2)
ax2.set_title("Wind Forecast Error vs. Price Difference");
ax3.scatter(x, y2)
ax3.set_title("Total Forecast Error vs. Price Difference");
