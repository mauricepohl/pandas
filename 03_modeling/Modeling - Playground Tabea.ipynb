# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../00_data/data_with_calc_fields.csv", sep=";", decimal=",")
data.head(5)
# Out:
#          date  hour             datetime  day_ahead_price  intraday_price  \
# 0  2016-01-01     0  2016-01-01 00:00:00            23.86           29.34
# 1  2016-01-01     1  2016-01-01 01:00:00            22.39           24.28
# 2  2016-01-01     2  2016-01-01 02:00:00            20.59           25.26
# 3  2016-01-01     3  2016-01-01 03:00:00            16.81           20.24
# 4  2016-01-01     4  2016-01-01 04:00:00            17.41           21.94
#
#    price_diff  solar_capacity  solar_generation_actual  wind_capacity  \
# 0       -5.48           39021                        0          44325
# 1       -1.89           39021                        0          44325
# 2       -4.67           39021                        0          44325
# 3       -3.43           39021                        0          44325
# 4       -4.53           39021                        0          44325
#
#    wind_generation_actual                   ...                    \
# 0                    8648                   ...
# 1                    8579                   ...
# 2                    8542                   ...
# 3                    8443                   ...
# 4                    8295                   ...
#
#    mov_avg_30_forecast_error  mov_avg_30_forecast_error_percent  \
# 0                    -2615.0                          -0.433449
# 1                    -1886.5                          -0.364098
# 2                    -1683.0                          -0.312332
# 3                    -1578.0                          -0.282319
# 4                    -1518.2                          -0.263257
#
#    mov_avg_30_wind_forecast_error_percent  \
# 0                               -0.433449
# 1                               -0.364098
# 2                               -0.312332
# 3                               -0.282319
# 4                               -0.263257
#
#    mov_avg_30_solar_forecast_error_percent  mov_avg_10_forecast_error_percent  \
# 0                                      NaN                          -0.433449
# 1                                      NaN                          -0.364098
# 2                                      NaN                          -0.312332
# 3                                      NaN                          -0.282319
# 4                                      NaN                          -0.263257
#
#    mov_avg_10_wind_forecast_error_percent  \
# 0                               -0.433449
# 1                               -0.364098
# 2                               -0.312332
# 3                               -0.282319
# 4                               -0.263257
#
#    mov_avg_10_solar_forecast_error_percent  mov_avg_1_forecast_error_percent  \
# 0                                      NaN                         -0.433449
# 1                                      NaN                         -0.364098
# 2                                      NaN                         -0.312332
# 3                                      NaN                         -0.282319
# 4                                      NaN                         -0.263257
#
#    mov_avg_1_wind_forecast_error_percent  \
# 0                              -0.433449
# 1                              -0.364098
# 2                              -0.312332
# 3                              -0.282319
# 4                              -0.263257
#
#    mov_avg_1_solar_forecast_error_percent
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 44 columns]

# %%
data.describe()
# Out:
#                hour  day_ahead_price  intraday_price    price_diff  \
# count  17542.000000     17542.000000    17542.000000  17542.000000
# mean      11.501083        31.588521       31.760971     -0.172451
# std        6.922035        15.483638       16.573758      6.831890
# min        0.000000      -130.090000     -155.520000   -106.080000
# 25%        6.000000        24.010000       23.912500     -2.950000
# 50%       12.000000        31.070000       31.300000     -0.030000
# 75%       17.750000        38.100000       38.747500      2.890000
# max       23.000000       163.520000      200.430000     62.710000
#
#        solar_capacity  solar_generation_actual  wind_capacity  \
# count    17542.000000             17542.000000   17542.000000
# mean     40306.320773              4015.817296   49534.509007
# std        926.067096              6175.382183    3376.046418
# min      39021.000000                 0.000000   44325.000000
# 25%      39484.000000                 0.000000   46779.000000
# 50%      40293.000000               115.000000   49569.000000
# 75%      41191.000000              6396.750000   52544.000000
# max      41951.000000             27634.000000   55790.000000
#
#        wind_generation_actual  wind_generation_forecast  \
# count            17542.000000              17542.000000
# mean             10239.222951              10113.905199
# std               8024.646794               7841.336319
# min                135.000000                291.000000
# 25%               4024.000000               4073.250000
# 50%               8041.500000               7980.500000
# 75%              14318.750000              13818.000000
# max              39231.000000              40368.000000
#
#        solar_generation_forecast      ...       total_capacity  \
# count               17542.000000      ...         17542.000000
# mean                 4041.170904      ...         89840.829780
# std                  6169.258742      ...          4298.537582
# min                     0.000000      ...         83346.000000
# 25%                     0.000000      ...         86263.000000
# 50%                   145.500000      ...         89862.000000
# 75%                  6458.000000      ...         93735.000000
# max                 27523.000000      ...         97741.000000
#
#        solar_utilization  wind_utilization  total_utilization  \
# count       17542.000000      17542.000000       17542.000000
# mean            0.099728          0.205624           0.158257
# std             0.153338          0.158013           0.102310
# min             0.000000          0.002875           0.003470
# 25%             0.000000          0.081989           0.074118
# 50%             0.002829          0.164009           0.137639
# 75%             0.158977          0.287704           0.226372
# max             0.675400          0.755437           0.558006
#
#        mov_avg_utilization        season       weekday  \
# count         17542.000000  17542.000000  17542.000000
# mean              0.156556      1.507696      3.007867
# std               0.026506      1.117376      2.000583
# min               0.061940      0.000000      0.000000
# 25%               0.135604      1.000000      1.000000
# 50%               0.154676      2.000000      3.000000
# 75%               0.174068      3.000000      5.000000
# max               0.231999      3.000000      6.000000
#
#        utilization_frac_t-1/mvg_avg  mov_avg_forecast_error         month
# count                  17518.000000            17542.000000  17542.000000
# mean                       1.013235              -74.603989      6.520237
# std                        0.642345              322.055780      3.449641
# min                        0.023094            -2615.000000      1.000000
# 25%                        0.489649             -294.505556      4.000000
# 50%                        0.903655             -113.022917      7.000000
# 75%                        1.430865              143.142361     10.000000
# max                        3.903779             1877.166667     12.000000
#
# [8 rows x 29 columns]

# %%
x = data["price_diff"]
y1 = data["solar_forecast_error"]
y2 = data["wind_forecast_error"]
y3 = data["forecast_error"]

f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20, 20), sharex=True)
ax1.scatter(x, y1)
ax1.set_title("Solar Forecast Error vs. Price Difference")
ax1.set_ylim(-5000,5000)
z = np.polyfit(x, y1, 1)
p = np.poly1d(z)
ax1.plot(x,p(x),"r--")
ax2.scatter(x, y2)
ax2.set_title("Wind Forecast Error vs. Price Difference");
ax2.set_ylim(-5000,5000)
z = np.polyfit(x, y2, 1)
p = np.poly1d(z)
ax2.plot(x,p(x),"r--")
ax3.scatter(x, y3)
ax3.set_title("Total Forecast Error vs. Price Difference");
ax3.set_ylim(-5000,5000)
z = np.polyfit(x, y2, 1)
p = np.poly1d(z)
ax3.plot(x,p(x),"r--")
for a in [ax1, ax2, ax3]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')

# %%
x = data["pricediff_percent"]
y1 = data["solar_forecast_error_percent"]
y2 = data["wind_forecast_error_percent"]
y3 = data["forecast_error_percent"]

f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20, 20), sharex=True, sharey=True)
ax1.scatter(x, y1)
ax1.set_ylim(-1,1)
ax1.set_xlim(-1,1)
ax1.set_title("Solar Forecast Error Percent vs. Price Difference")
ax2.scatter(x, y2)
ax2.set_title("Wind Forecast Error Percent vs. Price Difference");
ax3.scatter(x, y3)
ax3.set_title("Total Forecast Error Percent vs. Price Difference");
for a in [ax1, ax2, ax3]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')

# %%
x = data["hour"]
x1 = data["weekday"]
x2 = data["season"]
x3 = data["month"]
y = data["wind_forecast_error_percent"]
f, (ax, ax1, ax2, ax3) = plt.subplots(4, 1, figsize=(20, 20), sharex=False)
ax.scatter(x, y)
ax.set_title("Wind Forecast Error Percent vs. Time of day")
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
ax.plot(x,p(x),"g--")
ax1.scatter(x1, y)
ax1.set_title("Wind Forecast Error Percent vs. Weekday")
z = np.polyfit(x1, y, 1)
p = np.poly1d(z)
ax1.plot(x1,p(x1),"g--")
ax2.scatter(x2, y)
ax2.set_title("Wind Forecast Error Percent vs. Season")
z = np.polyfit(x2, y, 1)
p = np.poly1d(z)
ax2.plot(x2,p(x2),"g--")
ax3.scatter(x3, y)
ax3.set_title("Wind Forecast Error Percent vs. Month")
z = np.polyfit(x3, y, 1)
p = np.poly1d(z)
ax1.plot(x3,p(x3),"g--")
for a in [ax, ax1, ax2, ax3]:
    a.axhline(y=0, color='r')

# %%
import matplotlib.cm as cm
import numpy as np
month=13 # show all months, only first 3 month with month=4
x = data["wind_generation_forecast"]
colors = cm.rainbow(np.linspace(0, 1, month))
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
for y, c in zip(range(month), colors):
    ax.scatter(data[(data.month==y)]["wind_generation_forecast"], data[(data.month==y)]["wind_forecast_error_percent"], label=y, color=c, alpha=0.3)
ax.set_title("Wind Forecast Error Percent vs. Wind generation forecast")
ax.set_ylim(-1.5,1.5)
z = np.polyfit(x, data["wind_forecast_error_percent"], 1)
p = np.poly1d(z)
ax.plot(x,p(x),"r--")
plt.axhline(y=0, color='r')
plt.legend()
    
plt.show()

# %%
import matplotlib.cm as cm
import numpy as np
season=4 # show all seasons
x = data["wind_generation_forecast"]
colors = cm.rainbow(np.linspace(0, 1, season))
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
for y, c in zip(range(season), colors):
    ax.scatter(data[(data.season==y)]["wind_generation_forecast"], data[(data.season==y)]["wind_forecast_error_percent"], label=y, color=c, alpha=0.3)
ax.set_title("Wind Forecast Error Percent vs. Wind generation forecast")
ax.set_ylim(-1.5,1.5)
plt.axhline(y=0, color='r')
plt.legend()
plt.show()

# %%
from datetime import datetime
data["day"] = data["date"].map(lambda x: datetime.strptime(x, '%Y-%m-%d').day)
x = data["hour"]
x1 = data["weekday"]
x2 = data["season"]
x3 = data["month"]
x4 = data["day"]
x5 = data["date"]
y = data["solar_forecast_error_percent"]
f, (ax, ax1, ax2, ax3, ax4) = plt.subplots(5, 1, figsize=(20, 20), sharex=False)
ax.scatter(x, y)
ax.set_title("Solar Forecast Error Percent vs. Time of day")
ax1.scatter(x1, y)
ax1.set_title("Solar Forecast Error Percent vs. Weekday")
ax2.scatter(x2, y)
ax2.set_title("Solar Forecast Error Percent vs. Season")
ax3.scatter(x3, y)
ax3.set_title("Solar Forecast Error Percent vs. Month")
ax4.scatter(x4, y)
ax4.set_title("Solar Forecast Error Percent vs. Day")
#ax5.scatter(x5, y)
#ax5.set_title("Solar Forecast Error Percent vs. Date")
for a in [ax, ax1, ax2, ax3, ax4]:
    a.axhline(y=0, color='r')
plt.show()

# %%
x = data["solar_generation_forecast"]
y = data["solar_forecast_error"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 20), sharex=False)
ax.scatter(x, y)
ax.set_title("Solar Forecast Error Percent vs. Solar generation forecast")
#ax.set_ylim(-1.5,1.5)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
ax.plot(x,p(x),"r--")
plt.show()

# %%
x = data["wind_forecast_error_percent"].shift(24)
y = data["wind_forecast_error_percent"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y)
ax.set_title("Wind Forecast Error Percent vs. Wind forecast error day before")
ax.set_ylim(-1.5,1.5)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
plt.show()

# %%
#x = data["solar_forecast_error_percent"].shift(24)
x = data.solar_forecast_error_percent.shift(48).rolling(24,  min_periods=1).mean()
y = data["solar_forecast_error_percent"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y)
ax.set_title("Solar Forecast Error Percent vs. Solar forecast error day before")
ax.set_ylim(-1.5,1.5)
ax.set_xlim(-1.5,1.5)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
plt.show()

# %%
x = data["mov_avg_30_forecast_error_percent"].shift(24)
y = data["forecast_error_percent"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y)
ax.set_title("Total Forecast Error Percent vs. Total forecast error 30 day avg")
ax.set_ylim(-1,1)
ax.set_xlim(-0.2,0.2)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
plt.show()

# %%
x = data["mov_avg_30_wind_forecast_error_percent"].shift(24)
y = data["wind_forecast_error_percent"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y)
ax.set_title("Wind Forecast Error Percent vs. Wind forecast error 30 day avg")
ax.set_ylim(-1,1)
ax.set_xlim(-0.2,0.2)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
plt.show()

# %%
x = data["mov_avg_30_solar_forecast_error_percent"].shift(24)
y = data["solar_forecast_error_percent"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y)
ax.set_title("Solar Forecast Error Percent vs. Solar forecast error 30 day avg")
ax.set_ylim(-1.5,1.5)
ax.set_xlim(-0.5,0.5)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
plt.show()

# %%
x = data["mov_avg_10_wind_forecast_error_percent"].shift(24)
y = data["wind_forecast_error_percent"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y)
ax.set_title("Wind Forecast Error Percent vs. Wind forecast error 10 day avg")
ax.set_ylim(-1,1)
ax.set_xlim(-0.2,0.2)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
plt.show()

# %%
x = data["mov_avg_10_solar_forecast_error_percent"].shift(24)
y = data["solar_forecast_error_percent"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y)
ax.set_title("Solar Forecast Error Percent vs. Solar forecast error 10 day avg")
ax.set_ylim(-1.5,1.5)
ax.set_xlim(-0.5,0.5)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
plt.show()

# %%
x = data["pricediff_percent"]
y1 = data["solar_forecast_error_percent"]
y2 = data["wind_forecast_error_percent"]
y = data["forecast_error_percent"]
plt.hist2d(x,y,bins=100, range= [[-0.5, 0.5], [-0.5, 0.5]])
plt.show()

# %%
x = data["mov_avg_1_solar_forecast_error_percent"].shift(24)
y = data["solar_forecast_error_percent"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y)
ax.set_title("Solar Forecast Error Percent vs. Solar forecast error 10 day avg")
ax.set_ylim(-1.5,1.5)
ax.set_xlim(-0.5,0.5)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
plt.show()

# %%
x = data["mov_avg_1_wind_forecast_error_percent"].shift(24)
y = data["wind_forecast_error_percent"]
f, (ax) = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y)
ax.set_title("Solar Forecast Error Percent vs. Solar forecast error 10 day avg")
ax.set_ylim(-1.5,1.5)
ax.set_xlim(-0.5,0.5)
for a in [ax]:
    a.axhline(y=0, color='r')
    a.axvline(x=0, color='r')
plt.show()
