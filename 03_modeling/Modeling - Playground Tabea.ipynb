# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../00_data/data_with_calc_fields.csv", sep=";", decimal=",", index_col=["datetime"])
data.head(5)
# Out:
#                            date  hour  day_ahead_price  intraday_price  \
# datetime
# 2016-01-01 01:00:00  2016-01-01     1            22.39           24.28
# 2016-01-01 02:00:00  2016-01-01     2            20.59           25.26
# 2016-01-01 03:00:00  2016-01-01     3            16.81           20.24
# 2016-01-01 04:00:00  2016-01-01     4            17.41           21.94
# 2016-01-01 05:00:00  2016-01-01     5            17.02           23.50
#
#                      price_diff  solar_capacity  solar_generation_actual  \
# datetime
# 2016-01-01 01:00:00       -1.89           39021                        0
# 2016-01-01 02:00:00       -4.67           39021                        0
# 2016-01-01 03:00:00       -3.43           39021                        0
# 2016-01-01 04:00:00       -4.53           39021                        0
# 2016-01-01 05:00:00       -6.48           39021                        0
#
#                      wind_capacity  wind_generation_actual  \
# datetime
# 2016-01-01 01:00:00          44325                    8579
# 2016-01-01 02:00:00          44325                    8542
# 2016-01-01 03:00:00          44325                    8443
# 2016-01-01 04:00:00          44325                    8295
# 2016-01-01 05:00:00          44325                    7319
#
#                      solar_generation_forecast  wind_generation_forecast  \
# datetime
# 2016-01-01 01:00:00                          0                      7421
# 2016-01-01 02:00:00                          0                      7266
# 2016-01-01 03:00:00                          0                      7180
# 2016-01-01 04:00:00                          0                      7016
# 2016-01-01 05:00:00                          0                      6787
#
#                      total_generation_forecast  total_generation_actual  \
# datetime
# 2016-01-01 01:00:00                       7421                     8579
# 2016-01-01 02:00:00                       7266                     8542
# 2016-01-01 03:00:00                       7180                     8443
# 2016-01-01 04:00:00                       7016                     8295
# 2016-01-01 05:00:00                       6787                     7319
#
#                      wind_forecast_error  solar_forecast_error  \
# datetime
# 2016-01-01 01:00:00                -1158                     0
# 2016-01-01 02:00:00                -1276                     0
# 2016-01-01 03:00:00                -1263                     0
# 2016-01-01 04:00:00                -1279                     0
# 2016-01-01 05:00:00                 -532                     0
#
#                      forecast_error  forecast_error_percent  \
# datetime
# 2016-01-01 01:00:00           -1158               -0.156044
# 2016-01-01 02:00:00           -1276               -0.175612
# 2016-01-01 03:00:00           -1263               -0.175905
# 2016-01-01 04:00:00           -1279               -0.182298
# 2016-01-01 05:00:00            -532               -0.078385
#
#                      pricediff_percent  season  weekday
# datetime
# 2016-01-01 01:00:00          -0.084413       0        4
# 2016-01-01 02:00:00          -0.226809       0        4
# 2016-01-01 03:00:00          -0.204045       0        4
# 2016-01-01 04:00:00          -0.260195       0        4
# 2016-01-01 05:00:00          -0.380729       0        4

# %%
x = data["price_diff"]
y1 = data["solar_forecast_error"]
y2 = data["wind_forecast_error"]
y3 = data["forecast_error"]

f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20, 10), sharex=True)
ax1.scatter(x, y1)
ax1.set_title("Solar Forecast Error vs. Price Difference")
ax2.scatter(x, y2)
ax2.set_title("Wind Forecast Error vs. Price Difference");
ax3.scatter(x, y3)
ax3.set_title("Total Forecast Error vs. Price Difference");

# %%
x = data["price_diff"]
x1 = data["pricediff_percent"]
y1 = data["forecast_error_percent"]
f, (ax, ax3) = plt.subplots(2, 1, figsize=(20, 10), sharex=False)
ax.scatter(x, y1)
ax.set_title("Forecast Error Percent vs. Price Difference")
ax3.scatter(x1, y1)
ax3.set_title("Forecast Error Percent vs. Price Difference Percent")
# Out:
# Text(0.5,1,'Forecast Error Percent vs. Price Difference Percent')

# %%
x = data["hour"]
x1 = data["season"]
x2 = data["weekday"]
y1 = data["forecast_error"]
y2 = data["forecast_error_percent"]
f, (ax, ax1, ax2, ax3) = plt.subplots(4, 1, figsize=(20, 20), sharex=False)
ax.scatter(x, y1)
ax.set_title("Forecast Error vs. Time of day")
ax1.scatter(x1, y1)
ax1.set_title("Forecast Error vs. Season")
ax2.scatter(x1, y2)
ax2.set_title("Forecast Error Percent vs. Season")
ax3.scatter(x2, y2)
ax3.set_title("Forecast Error Percent vs. Weekday")
# Out:
# Text(0.5,1,'Forecast Error Percent vs. Weekday')
